# %% [markdown]
# ## Introduction To Machine learning for biomedical data analysis in Python (September 18, 2020)
#
#
# Instructor: Dr Mario Rosario Guarracino
#
# ---
#
# The notebooks have been prepared with an aim to introduce a workflow for data exploration and clean-up, visualization, clustering, classification and feature selection. Various rich online resources were referred to and some parts of the code have been modified and adapted for use in this course from the following sources:
#
# 1. **scikit-learn** https://scikit-learn.org/stable/user_guide.html#user-guide
#
#  Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B.,  Grisel, O., Blondel, M., Prettenhofer, P., Weiss, R., Dubourg, V. and Vanderplas, J., 2011. Scikit-learn: Machine learning in Python. the Journal of machine Learning research, 12, pp.2825-2830.
#
# 2. https://tylerburleigh.com/blog/modeling-the-heart-disease-uci-dataset/
#
# 3. Kaggle https://www.kaggle.com/ronitf/heart-disease-uci/notebooks
#
# 4. Machine learning mastery by Jason Brownlee https://machinelearningmastery.com/
#
# 5. https://github.com/ShubhankarRawat/Heart-Disease-Prediction
#
# 6. https://towardsdatascience.com/,
# https://towardsdatascience.com/diagnostic-for-heart-disease-with-machine-learning-81b064a3c1dd
#
# **Dataset**
#
# UCI Heart Disease Data Set (Cleveland)
#
# Source: https://archive.ics.uci.edu/ml/datasets/heart+disease
#
# Creators:
#
# 1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
# 2. University Hospital, Zurich, Switzerland: William Steinbrunn, M.D.
# 3. University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D.
# 4. V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.
#
# Donor:
#
# David W. Aha (aha '@' ics.uci.edu) (714) 856-8779
#
# Note: Also available from https://www.kaggle.com/ronitf/heart-disease-uci
#
#
# ---
